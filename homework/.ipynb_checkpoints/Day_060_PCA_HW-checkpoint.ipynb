# %% [markdown]
# # 使用手寫辨識資料集, 觀察 PCA 算法

# %% [markdown]
# # [作業目標]
# - 試著模仿範例寫法, 以變更參數後的 PCA + 邏輯斯迴歸判斷手寫辨識資料集, 觀察不同 component 下正確率的變化

# %% [markdown]
# # [作業重點]
# - 以手寫辨識資料集, 觀察變更參數後的 PCA 算法, 在取不同 component 時, PCA 解釋度與分類正確率如何變化 (In[5], Out[5])

# %%
# 載入套件
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
# 定義 PCA 與隨後的羅吉斯迴歸函數
# penalty 改為 L1, max_iter 改為 100
logistic = SGDClassifier(loss='log', penalty='l1', max_iter=100, tol=1e-5, random_state=0)
pca = PCA()
pipe = Pipeline(steps=[('pca', pca), ('logistic', logistic)])

# 載入手寫數字辨識集
digits = datasets.load_digits()
X_digits = digits.data
y_digits = digits.target

# %% [markdown]
# # 作業
# * 將參數 penalty 改為 L1, max_iter 改為 100, 觀察 PCA 與羅吉斯迴歸做手寫辨識的效果

# %%
# 先執行 GridSearchCV 跑出最佳參數
param_grid = {
    'pca__n_components': [4, 10, 20, 30, 40, 50, 64],
    'logistic__alpha': np.logspace(-4, 4, 5),
}
search = GridSearchCV(pipe, param_grid, iid=False, cv=5, return_train_score=False)
search.fit(X_digits, y_digits)
print("Best parameter (CV score=%0.3f):" % search.best_score_)
print(search.best_params_)
# Out:
# Best parameter (CV score=0.910):
# {'logistic__alpha': 0.0001, 'pca__n_components': 30}

# %%
# 繪製不同 components 的 PCA 解釋度
pca.fit(X_digits)

fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True, figsize=(6, 6))
ax0.plot(pca.explained_variance_ratio_, linewidth=2)
ax0.set_ylabel('PCA explained variance')

ax0.axvline(search.best_estimator_.named_steps['pca'].n_components, linestyle=':', label='n_components chosen')
ax0.legend(prop=dict(size=12))
# 繪製不同採樣點的分類正確率
results = pd.DataFrame(search.cv_results_)
components_col = 'param_pca__n_components'
best_clfs = results.groupby(components_col).apply(lambda g: g.nlargest(1, 'mean_test_score'))

best_clfs.plot(x=components_col, y='mean_test_score', yerr='std_test_score', legend=False, ax=ax1)
ax1.set_ylabel('Classification accuracy (val)')
ax1.set_xlabel('n_components')
plt.tight_layout()
plt.show()

# %%
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.053579      0.008747         0.000571        0.000077
# 1        0.037575      0.004895         0.000549        0.000039
# 2        0.053219      0.003277         0.000593        0.000167
# 3        0.064742      0.002361         0.000546        0.000053
# 4        0.075901      0.004591         0.000573        0.000028
# 5        0.089552      0.007405         0.000611        0.000057
# 6        0.109399      0.004287         0.000585        0.000018
# 7        0.048051      0.007407         0.000488        0.000025
# 8        0.051456      0.005447         0.000483        0.000006
# 9        0.090593      0.013530         0.000506        0.000022
# 10       0.155828      0.018971         0.000532        0.000021
# 11       0.279991      0.040160         0.000679        0.000039
# 12       0.426892      0.031533         0.000617        0.000022
# 13       0.562882      0.102767         0.000619        0.000008
# 14       0.045164      0.015003         0.000465        0.000015
# 15       0.051007      0.010315         0.000515        0.000048
# 16       0.092296      0.022507         0.000488        0.000004
# 17       0.125609      0.030486         0.000517        0.000023
# 18       0.158095      0.037760         0.000567        0.000024
# 19       0.191282      0.046258         0.000599        0.000053
# 20       0.231134      0.057589         0.000607        0.000021
# 21       0.149999      0.003382         0.000509        0.000048
# 22       0.240400      0.017087         0.000545        0.000028
# 23       0.347333      0.001771         0.000567        0.000017
# 24       0.488120      0.023136         0.000634        0.000092
# 25       0.679133      0.065582         0.000676        0.000132
# 26       0.951965      0.084777         0.000627        0.000112
# 27       1.116832      0.141620         0.000602        0.000038
# 28       0.019065      0.001776         0.000640        0.000182
# 29       0.023217      0.000880         0.000515        0.000093
# 30       0.035021      0.000625         0.000548        0.000107
# 31       0.045088      0.001449         0.000504        0.000027
# 32       0.057063      0.000894         0.000548        0.000050
# 33       0.067400      0.001829         0.000623        0.000124
# 34       0.076090      0.001541         0.000633        0.000078
#
#    param_logistic__alpha param_pca__n_components  \
# 0                 0.0001                       4
# 1                 0.0001                      10
# 2                 0.0001                      20
# 3                 0.0001                      30
# 4                 0.0001                      40
# 5                 0.0001                      50
# 6                 0.0001                      64
# 7                   0.01                       4
# 8                   0.01                      10
# 9                   0.01                      20
# 10                  0.01                      30
# 11                  0.01                      40
# 12                  0.01                      50
# 13                  0.01                      64
# 14                     1                       4
# 15                     1                      10
# 16                     1                      20
# 17                     1                      30
# 18                     1                      40
# 19                     1                      50
# 20                     1                      64
# 21                   100                       4
# 22                   100                      10
# 23                   100                      20
# 24                   100                      30
# 25                   100                      40
# 26                   100                      50
# 27                   100                      64
# 28                 10000                       4
# 29                 10000                      10
# 30                 10000                      20
# 31                 10000                      30
# 32                 10000                      40
# 33                 10000                      50
# 34                 10000                      64
#
#                                                params  split0_test_score  \
# 0   {'logistic__alpha': 0.0001, 'pca__n_components...           0.719780
# 1   {'logistic__alpha': 0.0001, 'pca__n_components...           0.912088
# 2   {'logistic__alpha': 0.0001, 'pca__n_components...           0.936813
# 3   {'logistic__alpha': 0.0001, 'pca__n_components...           0.928571
# 4   {'logistic__alpha': 0.0001, 'pca__n_components...           0.914835
# 5   {'logistic__alpha': 0.0001, 'pca__n_components...           0.909341
# 6   {'logistic__alpha': 0.0001, 'pca__n_components...           0.914835
# 7   {'logistic__alpha': 0.01, 'pca__n_components': 4}           0.782967
# 8   {'logistic__alpha': 0.01, 'pca__n_components':...           0.909341
# 9   {'logistic__alpha': 0.01, 'pca__n_components':...           0.925824
# 10  {'logistic__alpha': 0.01, 'pca__n_components':...           0.925824
# 11  {'logistic__alpha': 0.01, 'pca__n_components':...           0.931319
# 12  {'logistic__alpha': 0.01, 'pca__n_components':...           0.912088
# 13  {'logistic__alpha': 0.01, 'pca__n_components':...           0.912088
# 14   {'logistic__alpha': 1.0, 'pca__n_components': 4}           0.401099
# 15  {'logistic__alpha': 1.0, 'pca__n_components': 10}           0.516484
# 16  {'logistic__alpha': 1.0, 'pca__n_components': 20}           0.472527
# 17  {'logistic__alpha': 1.0, 'pca__n_components': 30}           0.472527
# 18  {'logistic__alpha': 1.0, 'pca__n_components': 40}           0.472527
# 19  {'logistic__alpha': 1.0, 'pca__n_components': 50}           0.472527
# 20  {'logistic__alpha': 1.0, 'pca__n_components': 64}           0.472527
# 21  {'logistic__alpha': 100.0, 'pca__n_components'...           0.101648
# 22  {'logistic__alpha': 100.0, 'pca__n_components'...           0.101648
# 23  {'logistic__alpha': 100.0, 'pca__n_components'...           0.101648
# 24  {'logistic__alpha': 100.0, 'pca__n_components'...           0.101648
# 25  {'logistic__alpha': 100.0, 'pca__n_components'...           0.101648
# 26  {'logistic__alpha': 100.0, 'pca__n_components'...           0.101648
# 27  {'logistic__alpha': 100.0, 'pca__n_components'...           0.101648
# 28  {'logistic__alpha': 10000.0, 'pca__n_component...           0.101648
# 29  {'logistic__alpha': 10000.0, 'pca__n_component...           0.101648
# 30  {'logistic__alpha': 10000.0, 'pca__n_component...           0.101648
# 31  {'logistic__alpha': 10000.0, 'pca__n_component...           0.101648
# 32  {'logistic__alpha': 10000.0, 'pca__n_component...           0.101648
# 33  {'logistic__alpha': 10000.0, 'pca__n_component...           0.101648
# 34  {'logistic__alpha': 10000.0, 'pca__n_component...           0.101648
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.591160           0.701950           0.711485
# 1            0.837017           0.880223           0.885154
# 2            0.861878           0.891365           0.943978
# 3            0.859116           0.913649           0.957983
# 4            0.861878           0.919220           0.929972
# 5            0.842541           0.927577           0.957983
# 6            0.867403           0.922006           0.955182
# 7            0.734807           0.807799           0.787115
# 8            0.864641           0.894150           0.907563
# 9            0.875691           0.905292           0.949580
# 10           0.861878           0.919220           0.955182
# 11           0.881215           0.916435           0.946779
# 12           0.861878           0.894150           0.935574
# 13           0.875691           0.891365           0.938375
# 14           0.254144           0.523677           0.400560
# 15           0.395028           0.437326           0.478992
# 16           0.334254           0.437326           0.478992
# 17           0.417127           0.440111           0.478992
# 18           0.417127           0.440111           0.478992
# 19           0.417127           0.440111           0.478992
# 20           0.417127           0.440111           0.478992
# 21           0.099448           0.100279           0.098039
# 22           0.099448           0.100279           0.098039
# 23           0.099448           0.100279           0.098039
# 24           0.099448           0.100279           0.098039
# 25           0.099448           0.100279           0.098039
# 26           0.099448           0.100279           0.098039
# 27           0.099448           0.100279           0.098039
# 28           0.099448           0.100279           0.098039
# 29           0.099448           0.100279           0.098039
# 30           0.099448           0.100279           0.098039
# 31           0.099448           0.100279           0.098039
# 32           0.099448           0.100279           0.098039
# 33           0.099448           0.100279           0.098039
# 34           0.099448           0.100279           0.098039
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.670423         0.678959        0.046977               14
# 1            0.859155         0.874727        0.025296               12
# 2            0.876056         0.902018        0.032772                8
# 3            0.892958         0.910455        0.033284                1
# 4            0.887324         0.902646        0.024766                7
# 5            0.881690         0.903826        0.039429                6
# 6            0.876056         0.907096        0.032042                5
# 7            0.757746         0.774087        0.025279               13
# 8            0.842254         0.883590        0.026142               11
# 9            0.884507         0.908179        0.027017                4
# 10           0.881690         0.908759        0.033125                3
# 11           0.873239         0.909797        0.028384                2
# 12           0.850704         0.890879        0.031347               10
# 13           0.861972         0.895898        0.027005                9
# 14           0.461972         0.408290        0.089519               21
# 15           0.369014         0.439369        0.053734               15
# 16           0.371831         0.418986        0.056933               20
# 17           0.369014         0.435554        0.040104               16
# 18           0.369014         0.435554        0.040104               16
# 19           0.369014         0.435554        0.040104               16
# 20           0.369014         0.435554        0.040104               16
# 21           0.101408         0.100164        0.001326               22
# 22           0.101408         0.100164        0.001326               22
# 23           0.101408         0.100164        0.001326               22
# 24           0.101408         0.100164        0.001326               22
# 25           0.101408         0.100164        0.001326               22
# 26           0.101408         0.100164        0.001326               22
# 27           0.101408         0.100164        0.001326               22
# 28           0.101408         0.100164        0.001326               22
# 29           0.101408         0.100164        0.001326               22
# 30           0.101408         0.100164        0.001326               22
# 31           0.101408         0.100164        0.001326               22
# 32           0.101408         0.100164        0.001326               22
# 33           0.101408         0.100164        0.001326               22
# 34           0.101408         0.100164        0.001326               22
