# %% [markdown]
# # 作業目標:
#     運用 Keras 模組建構CNN, 了解 CNN 的架構

# %% [markdown]
# # 作業重點
# (1)嘗試比對 Dense 與 layers.Conv2D 架構NN 的差異
#
# (2) 有沒有Pooling layer, 對於參數量的差異
#
# 注意: input_shape 請勿修改

# %%
#導入相關模組
import keras
from keras import layers
from keras import models
from keras.models import Sequential
from keras.layers import Conv2D, Activation, MaxPooling2D, Flatten, Dense

#確認keras 版本
print(keras.__version__)
# Out:
# Using TensorFlow backend.
# 2.2.4

# %%
'''
model = Sequential([
    Dense(xxx),
    Activation(xxx),
    Dense(xxx),
    Activation(xxx),
])
'''
#model.summary()

model = Sequential([
    Dense(200, input_shape=(28, 28, 1)),
    Activation('relu'),
    Dense(100),
    Activation('relu'),
])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 28, 28, 200)       400
# _________________________________________________________________
# activation_5 (Activation)    (None, 28, 28, 200)       0
# _________________________________________________________________
# dense_6 (Dense)              (None, 28, 28, 100)       20100
# _________________________________________________________________
# activation_6 (Activation)    (None, 28, 28, 100)       0
# =================================================================
# Total params: 20,500
# Trainable params: 20,500
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Pooling

# %% [markdown]
# # layers.Conv2D 模型, 用作比對
#
# ![CNN_Model.png](attachment:CNN_Model.png)

# %%
'''
#建立一個序列模型
model = models.Sequential()
#建立兩個卷績層, 32 個內核, 內核大小 3x3, 
#輸入影像大小 28x28x1

#建立一個全連接層
model.add(Dense(units=100))
model.add(Activation('relu'))

#建立一個輸出層, 並採用softmax
model.add(Dense(units=10))
model.add(Activation('softmax'))
'''
#model.summary()

model = models.Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(28, 28, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(32, (3, 3)))
model.add(MaxPooling2D(2, 2))

model.add(Flatten())

model.add(Dense(units=100))
model.add(Activation('relu'))

model.add(Dense(units=10))
model.add(Activation('softmax'))

model.summary()
# Out:
# W0810 08:00:02.274175 140188292630400 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 800)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               80100
# _________________________________________________________________
# activation_7 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                1010
# _________________________________________________________________
# activation_8 (Activation)    (None, 10)                0
# =================================================================
# Total params: 90,678
# Trainable params: 90,678
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### No Pooling

# %%
model = models.Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(28, 28, 1)))
# model.add(MaxPooling2D(2, 2))
model.add(Conv2D(32, (3, 3)))
# model.add(MaxPooling2D(2, 2))

model.add(Flatten())

model.add(Dense(units=100))
model.add(Activation('relu'))

model.add(Dense(units=10))
model.add(Activation('softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 24, 24, 32)        9248
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_9 (Dense)              (None, 100)               1843300
# _________________________________________________________________
# activation_9 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                1010
# _________________________________________________________________
# activation_10 (Activation)   (None, 10)                0
# =================================================================
# Total params: 1,853,878
# Trainable params: 1,853,878
# Non-trainable params: 0
# _________________________________________________________________
